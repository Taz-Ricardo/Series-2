# %% [markdown]
# Codigos que pueden ser utiles

# %%
library(tidyr)
library(dplyr)

# %%
df <- AFP%>%select(Date, Habitat.A, Cuprum.A,ProVida.A,PlanVital.A)
df
# Out:
#     Date    Habitat.A Cuprum.A ProVida.A PlanVital.A
# 1   2005-08 -0.84     -0.62    -0.60      -0.79
# 2   2005-09  3.26      3.03     3.44       3.15
# 3   2005-10 -4.16     -4.17    -4.49      -4.34
# 4   2005-11  2.15      2.11     2.50       2.08
# 5   2005-12  1.34      1.64     1.85       1.49
# 6   2006-01  7.03      7.06     7.39       7.48
# 7   2006-02  0.73      0.75     0.74       0.68
# 8   2006-03  1.44      1.27     1.25       1.45
# 9   2006-04  3.07      3.19     3.30       3.10
# 10  2006-05 -3.96     -3.84    -4.02      -3.90
# 11  2006-06 -3.66     -3.48    -3.44      -3.33
# 12  2006-07  2.42      2.52     2.25       2.30
# 13  2006-08  1.54      1.72     1.61       1.63
# 14  2006-09  1.06      0.98     0.90       0.97
# 15  2006-10  3.17      2.87     2.94       3.19
# 16  2006-11  2.88      2.80     3.06       2.87
# 17  2006-12  4.94      4.61     4.84       5.10
# 18  2007-01  1.89      1.66     1.70       1.79
# ...
